# %% [markdown]
# # OpenCV

# %%
#image load

import cv2

img = cv2.imread('Cat_picture/cat1.jpg')
img.shape
# Out:
# (1797, 2673, 3)

# %%
# Show image

import cv2
from matplotlib import pyplot as plt

img = cv2.imread('cat_picture/cat1.jpg')
plt.imshow(img)

# %%
#BGR to RGB 

import cv2
from matplotlib import pyplot as plt

img = cv2.imread('Cat_picture/cat1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
